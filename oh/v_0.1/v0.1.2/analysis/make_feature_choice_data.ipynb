# %%
import pandas as pd

# %%
data_path = "../data"
file_name = '/winequalityN.csv'
new_file_name = '/feature_choice.csv'

# %%
data_set = pd.read_csv(data_path + file_name, delimiter =',')

# %%
feature_choice = data_set.drop(columns = ['type', 'residual sugar', 'chlorides', 'free sulfur dioxide','density'], axis = 1)
print(feature_choice)
# Out:
#       fixed acidity  volatile acidity  citric acid  total sulfur dioxide  \
# 0               7.0             0.270         0.36                 170.0
# 1               6.3             0.300         0.34                 132.0
# 2               8.1             0.280         0.40                  97.0
# 3               7.2             0.230         0.32                 186.0
# 4               7.2             0.230         0.32                 186.0
# 5               8.1             0.280         0.40                  97.0
# 6               6.2             0.320         0.16                 136.0
# 7               7.0             0.270         0.36                 170.0
# 8               6.3             0.300         0.34                 132.0
# 9               8.1             0.220         0.43                 129.0
# 10              8.1             0.270         0.41                  63.0
# 11              8.6             0.230         0.40                 109.0
# ...

# %%
feature_choice.to_csv(data_path + new_file_name, mode = 'w')
